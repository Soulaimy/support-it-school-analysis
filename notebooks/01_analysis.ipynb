# %%
import pandas as pd

tickets = pd.read_csv("../data/tickets_support.csv")
pc = pd.read_csv("../data/parc_informatique.csv")

tickets.head()
# Out:
#   ticket_id        date    category priority  resolution_time  status
# 0      T001  2026-01-02        Wifi    Haute                4  Résolu
# 1      T002  2026-01-03      Compte    Haute                2  Résolu
# 2      T003  2026-01-03  Imprimante  Moyenne                6  Résolu
# 3      T004  2026-01-04       Teams    Haute                5  Résolu
# 4      T005  2026-01-05        Wifi    Haute                3  Résolu

# %%
import pandas as pd

# %%
tickets.shape
# Out:
# (10, 6)

# %%
pc.shape
# Out:
# (8, 8)

# %%
pc.head()
# Out:
#    pc_id            model    state   loan_date return_date    status student  \
# 0  PC001    Dell Latitude      Bon  2026-01-01  2026-06-01      Prêt  ETU001
# 1  PC002       HP ProBook    Moyen  2026-01-03         NaN  En cours  ETU002
# 2  PC003  Lenovo ThinkPad      Bon  2026-01-05  2026-05-20     Rendu  ETU003
# 3  PC004      MacBook Air      Bon  2026-01-07         NaN  En cours  ETU004
# 4  PC005    Dell Latitude  Mauvais  2026-01-10         NaN  En cours  ETU005
#
#    formation
# 0       Info
# 1       Data
# 2  Marketing
# 3     Design
# 4       Data

# %%
tickets["category"].value_counts()
# Out:
# category
# Wifi            3
# Compte          1
# Imprimante      1
# Teams           1
# Logiciel        1
# PC              1
# ENT             1
# Mot de passe    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

tickets["category"].value_counts().plot(kind="bar")

plt.title("Nombre de tickets par catégorie")
plt.xlabel("Catégorie")
plt.ylabel("Nombre de tickets")

plt.show()

# %%
tickets["resolution_time"].mean()
# Out:
# np.float64(5.0)
